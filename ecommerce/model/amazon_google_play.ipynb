# %% [markdown]
# This script builds a model for classifying two products from different retailers as being the same or not, based on data from the retailers. In currently uses the following features:
# - Cosine distance between:
#     - Product names
#     - Product descriptions
#
# The last cell finds inter-retailer price differences for products known to be the same

# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# Import a bunch of libraries.
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import cosine

# Set the randomizer seed so results are the same each time.
np.random.seed(0)

# %%
# Load the data
amazon = pd.read_csv("amazon.csv", na_filter=False, encoding="ISO-8859-1")
google = pd.read_csv("googleproducts.csv", na_filter=False, encoding="ISO-8859-1")
amazon_google = pd.read_csv("Amzon_GoogleProducts_perfectMapping.csv", encoding="ISO-8859-1")
amazon_google
# Out:
#         idAmazon                                       idGoogleBase
# 0     b000jz4hqo  http://www.google.com/base/feeds/snippets/1844...
# 1     b00004tkvy  http://www.google.com/base/feeds/snippets/1844...
# 2     b000g80lqo  http://www.google.com/base/feeds/snippets/1844...
# 3     b0006se5bq  http://www.google.com/base/feeds/snippets/1842...
# 4     b00021xhzw  http://www.google.com/base/feeds/snippets/1843...
# 5     b0000dbykm  http://www.google.com/base/feeds/snippets/1843...
# 6     b0000dbykm  http://www.google.com/base/feeds/snippets/1836...
# 7     b00029bqa2  http://www.google.com/base/feeds/snippets/1843...
# 8     b0007prnjo  http://www.google.com/base/feeds/snippets/1843...
# 9     b000i82j80  http://www.google.com/base/feeds/snippets/1843...
# 10    b000i82j80  http://www.google.com/base/feeds/snippets/6054...
# 11    b000in6u62  http://www.google.com/base/feeds/snippets/1843...
# 12    b00006hvvo  http://www.google.com/base/feeds/snippets/3409...
# 13    b00006hvvo  http://www.google.com/base/feeds/snippets/9687...
# 14    b0000ycfcw  http://www.google.com/base/feeds/snippets/3211...
# 15    b00066dd5m  http://www.google.com/base/feeds/snippets/9494...
# 16    b00002sac9  http://www.google.com/base/feeds/snippets/8401...
# 17    b000bcz8ng  http://www.google.com/base/feeds/snippets/3077...
# 18    b000fm18vi  http://www.google.com/base/feeds/snippets/3620...
# 19    b00009apna  http://www.google.com/base/feeds/snippets/3435...
# 20    b0009rgzgm  http://www.google.com/base/feeds/snippets/1883...
# 21    b000ap2wyw  http://www.google.com/base/feeds/snippets/2622...
# 22    b000o24l3q  http://www.google.com/base/feeds/snippets/5181...
# 23    b000o24l3q  http://www.google.com/base/feeds/snippets/9489...
# 24    b0009jlux8  http://www.google.com/base/feeds/snippets/4923...
# 25    b000cszg2m  http://www.google.com/base/feeds/snippets/5032...
# 26    b00023azve  http://www.google.com/base/feeds/snippets/4949...
# 27    b000ndicuy  http://www.google.com/base/feeds/snippets/2263...
# 28    b0000ycfdq  http://www.google.com/base/feeds/snippets/4188...
# 29    b0007yepy6  http://www.google.com/base/feeds/snippets/4783...
# ...          ...                                                ...
# 1270  b000jx5shs  http://www.google.com/base/feeds/snippets/1757...
# 1271  b000ezmxz6  http://www.google.com/base/feeds/snippets/1812...
# 1272  b000v9yxj4  http://www.google.com/base/feeds/snippets/1752...
# 1273  b000pienka  http://www.google.com/base/feeds/snippets/1752...
# 1274  b000fb9w3a  http://www.google.com/base/feeds/snippets/1794...
# 1275  b000szyqam  http://www.google.com/base/feeds/snippets/1811...
# 1276  b000jx84va  http://www.google.com/base/feeds/snippets/1783...
# 1277  b000nkklwy  http://www.google.com/base/feeds/snippets/1827...
# 1278  b000in6tnq  http://www.google.com/base/feeds/snippets/1825...
# 1279  b000iflerk  http://www.google.com/base/feeds/snippets/1777...
# 1280  b000exu99k  http://www.google.com/base/feeds/snippets/1764...
# 1281  b000kmaa8a  http://www.google.com/base/feeds/snippets/1764...
# 1282  b000lptgc2  http://www.google.com/base/feeds/snippets/1762...
# 1283  b00005auzh  http://www.google.com/base/feeds/snippets/1764...
# 1284  b000ndibhi  http://www.google.com/base/feeds/snippets/8042...
# 1285  b00005rd70  http://www.google.com/base/feeds/snippets/1769...
# 1286  b0000cdvuh  http://www.google.com/base/feeds/snippets/1769...
# 1287  b000rsk7k8  http://www.google.com/base/feeds/snippets/1766...
# 1288  b0009x6qew  http://www.google.com/base/feeds/snippets/1830...
# 1289  b000tdgyks  http://www.google.com/base/feeds/snippets/1768...
# 1290  b000pihtbk  http://www.google.com/base/feeds/snippets/1803...
# 1291  b000pihtbk  http://www.google.com/base/feeds/snippets/9522...
# 1292  b0002yiuns  http://www.google.com/base/feeds/snippets/1760...
# 1293  b000in8mj0  http://www.google.com/base/feeds/snippets/1770...
# 1294  b000cs3s2c  http://www.google.com/base/feeds/snippets/1771...
# 1295  b00005bigp  http://www.google.com/base/feeds/snippets/1773...
# 1296  b000h1df7w  http://www.google.com/base/feeds/snippets/1773...
# 1297  b000p9cr66  http://www.google.com/base/feeds/snippets/1772...
# 1298  b000p9cr66  http://www.google.com/base/feeds/snippets/1321...
# 1299  b000j588g4  http://www.google.com/base/feeds/snippets/1773...
#
# [1300 rows x 2 columns]

# %%
# create a table with all the matched products
data = pd.merge(amazon, amazon_google, left_on="id", right_on="idAmazon")
data = pd.merge(data, google, left_on="idGoogleBase", right_on="id")
data = data[['title', 'description_x', 'name', 'description_y']]
data.columns = ['amazon_name', 'amazon_description', 'google_name', 'google_description']
data['match'] = np.ones(data.shape[0])
data
# Out:
#         idAmazon                                       idGoogleBase
# 0     b000jz4hqo  http://www.google.com/base/feeds/snippets/1020...
# 1     b00004tkvy  http://www.google.com/base/feeds/snippets/8112...
# 2     b000g80lqo  http://www.google.com/base/feeds/snippets/5733...
# 3     b0006se5bq  http://www.google.com/base/feeds/snippets/1730...
# 4     b00021xhzw  http://www.google.com/base/feeds/snippets/1838...
# 5     b0000dbykm  http://www.google.com/base/feeds/snippets/1745...
# 6     b0000dbykm  http://www.google.com/base/feeds/snippets/1754...
# 7     b00029bqa2  http://www.google.com/base/feeds/snippets/1211...
# 8     b0007prnjo  http://www.google.com/base/feeds/snippets/2263...
# 9     b000i82j80  http://www.google.com/base/feeds/snippets/1264...
# 10    b000i82j80  http://www.google.com/base/feeds/snippets/1770...
# 11    b000in6u62  http://www.google.com/base/feeds/snippets/1798...
# 12    b00006hvvo  http://www.google.com/base/feeds/snippets/1368...
# 13    b00006hvvo  http://www.google.com/base/feeds/snippets/1759...
# 14    b0000ycfcw  http://www.google.com/base/feeds/snippets/1837...
# 15    b00066dd5m  http://www.google.com/base/feeds/snippets/1333...
# 16    b00002sac9  http://www.google.com/base/feeds/snippets/4433...
# 17    b000bcz8ng  http://www.google.com/base/feeds/snippets/9352...
# 18    b000fm18vi  http://www.google.com/base/feeds/snippets/1366...
# 19    b00009apna  http://www.google.com/base/feeds/snippets/1694...
# 20    b0009rgzgm  http://www.google.com/base/feeds/snippets/1719...
# 21    b000ap2wyw  http://www.google.com/base/feeds/snippets/3911...
# 22    b000o24l3q  http://www.google.com/base/feeds/snippets/7544...
# 23    b000o24l3q  http://www.google.com/base/feeds/snippets/1367...
# 24    b0009jlux8  http://www.google.com/base/feeds/snippets/1307...
# 25    b000cszg2m  http://www.google.com/base/feeds/snippets/9859...
# 26    b00023azve  http://www.google.com/base/feeds/snippets/1294...
# 27    b000ndicuy  http://www.google.com/base/feeds/snippets/1843...
# 28    b0000ycfdq  http://www.google.com/base/feeds/snippets/3576...
# 29    b0007yepy6  http://www.google.com/base/feeds/snippets/1823...
# ...          ...                                                ...
# 1270  b000jx5shs  http://www.google.com/base/feeds/snippets/1666...
# 1271  b000ezmxz6  http://www.google.com/base/feeds/snippets/1843...
# 1272  b000v9yxj4  http://www.google.com/base/feeds/snippets/1346...
# 1273  b000pienka  http://www.google.com/base/feeds/snippets/1339...
# 1274  b000fb9w3a  http://www.google.com/base/feeds/snippets/3987...
# 1275  b000szyqam  http://www.google.com/base/feeds/snippets/1591...
# 1276  b000jx84va  http://www.google.com/base/feeds/snippets/1844...
# 1277  b000nkklwy  http://www.google.com/base/feeds/snippets/1837...
# 1278  b000in6tnq  http://www.google.com/base/feeds/snippets/1697...
# 1279  b000iflerk  http://www.google.com/base/feeds/snippets/1740...
# 1280  b000exu99k  http://www.google.com/base/feeds/snippets/1127...
# 1281  b000kmaa8a  http://www.google.com/base/feeds/snippets/1049...
# 1282  b000lptgc2  http://www.google.com/base/feeds/snippets/3752...
# 1283  b00005auzh  http://www.google.com/base/feeds/snippets/9655...
# 1284  b000ndibhi  http://www.google.com/base/feeds/snippets/1794...
# 1285  b00005rd70  http://www.google.com/base/feeds/snippets/1736...
# 1286  b0000cdvuh  http://www.google.com/base/feeds/snippets/1723...
# 1287  b000rsk7k8  http://www.google.com/base/feeds/snippets/1837...
# 1288  b0009x6qew  http://www.google.com/base/feeds/snippets/1302...
# 1289  b000tdgyks  http://www.google.com/base/feeds/snippets/1842...
# 1290  b000pihtbk  http://www.google.com/base/feeds/snippets/1298...
# 1291  b000pihtbk  http://www.google.com/base/feeds/snippets/1841...
# 1292  b0002yiuns  http://www.google.com/base/feeds/snippets/1836...
# 1293  b000in8mj0  http://www.google.com/base/feeds/snippets/1844...
# 1294  b000cs3s2c  http://www.google.com/base/feeds/snippets/1340...
# 1295  b00005bigp  http://www.google.com/base/feeds/snippets/1361...
# 1296  b000h1df7w  http://www.google.com/base/feeds/snippets/1745...
# 1297  b000p9cr66  http://www.google.com/base/feeds/snippets/1327...
# 1298  b000p9cr66  http://www.google.com/base/feeds/snippets/1467...
# 1299  b000j588g4  http://www.google.com/base/feeds/snippets/1794...
#
# [1300 rows x 2 columns]

# %%
# create table of mismatches
def findDifferent(amazonId):
    googleMatches = amazon_google.loc[amazon_google.idAmazon==amazonId].idGoogleBase
    googleNotMatches = google.loc[google.id.isin(googleMatches)==False]
    googleNotMatches = googleNotMatches.iloc[np.random.permutation(len(googleNotMatches) - 1)]
    return googleNotMatches[:1].iloc[0].id

amazon_not_google = pd.DataFrame(amazon_google.idAmazon)
amazon_not_google['idGoogleBase'] = amazon_not_google.idAmazon.map(findDifferent)
amazon_not_google

# %%
# add mismatched examples to matched ones
moreData = pd.merge(amazon, amazon_not_google, left_on="id", right_on="idAmazon")
moreData = pd.merge(moreData, google, left_on="idGoogleBase", right_on="id")
moreData = moreData[['title', 'description_x', 'name', 'description_y']]
moreData.columns = ['amazon_name', 'amazon_description', 'google_name', 'google_description']
moreData['match'] = np.zeros(moreData.shape[0])
data = pd.concat([data, moreData])
data
# Out:
#                                             amazon_name  \
# 0       clickart 950 000 - premier image pack (dvd-rom)
# 1      noah's ark activity center (jewel case ages 3-8)
# 2     peachtree by sage premium accounting for nonpr...
# 3                               singing coach unlimited
# 4     adobe after effects professional 6.5 upgrade f...
# 5                    mia's math adventure: just in time
# 6                    mia's math adventure: just in time
# 7     disney's 1st & 2nd grade bundle (pixar 1st gra...
# 8                              paper art: gift wrapping
# 9                                   spy sweeper spanish
# 10                                  spy sweeper spanish
# 11                        omnioutliner professional 3.0
# 12                       upg sgms 1000 incremental node
# 13                       upg sgms 1000 incremental node
# 14                                       the human body
# 15    school zone pencil-pal software big phonics (c...
# 16               millie's math house ages 3-7 (win/mac)
# 17                         world book encyclopedia 2006
# 18                            musicalis guitar workshop
# 19              the printshop 20 professional publisher
# 20                                data protection suite
# 21                             kids power fun for girls
# 22                       adobe premiere pro cs3 upgrade
# 23                       adobe premiere pro cs3 upgrade
# 24                   i copy dvds 2 professional edition
# 25                         gen-x media made easy vol. 3
# 26           family tree maker 11.2 collector's edition
# 27                            adobe fireworks cs3 [mac]
# 28                                            dinosaurs
# 29                         instant home design 3.0 [lb]
# ...                                                 ...
# 1270              video patrol 5.0 by honest technology
# 1271                                       snap! kakuro
# 1272   instant immersion american sign language win/mac
# 1273                                  simple slide show
# 1274                        printmaster platinum v 17.0
# 1275                     street atlas usa 2007 plus dvd
# 1276  onone essentials for adobe photoshop elements ...
# 1277                        emedia blues guitar legends
# 1278  age of empires iii: the warchiefs expansion pa...
# 1279  delorme topo usa mapping software 6.0 east region
# 1280                               northstar for pc/mac
# 1281           make music allegro 2007 labpack - 5 user
# 1282                     liquid ledger personal finance
# 1283                            sportsman's double play
# 1284                  jumpstart advanced preschool v2.0
# 1285               visual thesaurus the - thinkmap inc.
# 1286             phonics success essentials: grades 7-9
# 1287  adobe creative suite cs3 web standard upsell [...
# 1288                    train sim modeler design studio
# 1289                learn to play keyboard (jewel case)
# 1290                                     ufo afterlight
# 1291  instant immersion italian deluxe v2.0 (large box)
# 1292                        enemy territory: quake wars
# 1293  weekly reader mastering elementary/middle scho...
# 1294  weekly reader mastering elementary/middle scho...
# 1295                      sentinel: descendants in time
# 1296                           photostory on cd & dvd 5
# 1297                                             shapes
# 1298              dragon naturally speaking standard v9
# 1299                                       mediarecover
#
#                                      amazon_description  \
# 0
# 1
# 2     peachtree premium accounting for nonprofits 20...
# 3     singing coach unlimited - electronic learning ...
# 4     upgrade only; installation of after effects st...
# 5     in mia's math adventure: just in time children...
# 6     in mia's math adventure: just in time children...
# 7     disney's 1st & 2nd grade bundle will help your...
# 8     how many times have you heard that it's the th...
# 9
# 10
# 11
# 12    today enterprises and service providers face i...
# 13    today enterprises and service providers face i...
# 14    in topics presents the human body you'll uncov...
# 15
# 16    now featuring addition subtraction and countin...
# 17    the world book encyclopedia 2006 is a truly st...
# 18    chord display / create your own chords / digit...
# 19    the complete and easy publishing solution for ...
# 20    if you use a computer you're at risk for syste...
# 21
# 22    note: this is the upgrade version of adobe pre...
# 23    note: this is the upgrade version of adobe pre...
# 24    icopydvds2 pro edition contains all you need t...
# 25    media made easy vol. 3 is your front-row ticke...
# 26    whether you're an avid family historian or a c...
# 27    accelerate web design and development with ado...
# 28
# 29    software suite helps you create customized bef...
# ...                                                 ...
# 1270  turn your computer and pc camera into a powerf...
# 1271                        snap! kakuro (win 98 me xp)
# 1272  instant immersion asl teaches beginners americ...
# 1273  in simple slideshow you have everything you ne...
# 1274  printmaster platinum 17 lets creative home use...
# 1275  are you a serious road warrior looking for the...
# 1276
# 1277  learn how to play classic blues songs from the...
# 1278  age of empires iii: the war chiefs is the new ...
# 1279  topo usa 6.0 eastern region makes it a snap to...
# 1280  northstar (win 98 me nt 2000 xp/mac 10.3.8 or ...
# 1281
# 1282  personal finance software for max os x. liquid...
# 1283  sportsman's double play gives you the very bes...
# 1284  jumpstart advanced preschool is the complete g...
# 1285  thinkmap's visual thesaurus is a new type of i...
# 1286  this package contains learning in 6 different ...
# 1287  note: this is the upsell version of adobe crea...
# 1288  with train sim modeler you can create 3d train...
# 1289  with learn to play keyboard you can avoid shel...
# 1290  ufo: afterlight mixes squad-based combat with ...
# 1291  with instant immersion italian deluxe you'll g...
# 1292                    enemy territory: quake wars mac
# 1293
# 1294
# 1295  sentinel: descendants in time gives you a chan...
# 1296  magix photostory on cd and dvd 5 answers the q...
# 1297
# 1298  dragon naturallyspeaking 9 (standard edition) ...
# 1299  mediarecover gives you the ability to recover ...
#
#                                             google_name  \
# 0        clickart 950000 - premier image pack (dvd-rom)
# 1     the beginners bible: noah's ark activity cente...
# 2     sage (ptree) - vernfp2007rt - premium accounti...
# 3     singing coach unlimited - electronic learning ...
# 4     adobe software 22070152 after effects 6.5 pbupgrd
# 5     kutoka interactive 61208 mia's math adventure:...
# 6     kutoka interactive 61208 - mias math adventure...
# 7                     disney learning 1st-2nd grade win
# 8                     paper art volume 2: gift wrapping
# 9     webroot software inc - 31250 - spy sweeper spa...
# 10    webroot software inc 31250 - spy sweeper spani...
# 11                omnioutliner professional 3.0 for mac
# 12              sonicwall gms 1000n-incremental lic upg
# 13                           sonicwall gms 1000 upgrade
# 14                          topics presents: human body
# 15                               pencil-pal big phonics
# 16                                   millies math house
# 17                                      world book 2006
# 18                  musicalis universal guitar workshop
# 19                           printshop 20 pro publisher
# 20                  data protection security suite 2005
# 21                             kids power fun for girls
# 22                       adobe premiere pro cs3 upgrade
# 23                         premiere pro cs3 mac upgrade
# 24                    i copydvds 2 professional edition
# 25                             media made easy volume 3
# 26             family tree maker 11 collector's edition
# 27                                  adobe fireworks cs3
# 28                            topics presents:dinosaurs
# 29                              instant home design 3.0
# ...                                                 ...
# 1270          abacus software 5562 chopper havoc for pc
# 1271  freeverse software 4024 robin hood: the legend...
# 1272  kd lang tony bennett mike garson yamaha tony b...
# 1273                         studio ultimate version 11
# 1274           apple software t9164ll/a logic express 6
# 1275  redshift 5 (national geographic presents) (win...
# 1276                             fogware hyb places dvd
# 1277  turtle-beach used wave 2-0 20 software for win...
# 1278  quicken(r) quickbooks(r) microsoft money(r) an...
# 1279  dragon naturally speaking (v9.0) preferred wir...
# 1280             avanquest encyclopedia britannica 2006
# 1281                          spyware x-terminator 2005
# 1282  yamaha vision of love - hits of mariah carey -...
# 1283                         cyberlink power director 3
# 1284                           quickstudy us government
# 1285  madison media software asams7000 - sony creati...
# 1286  encore software 11620 - axis & allies - win 98...
# 1287           csdc more brain games - on hand software
# 1288  graphic simulations corporation f/a-18 operati...
# 1289  t3558a hp storageworks secure path for hp-ux w...
# 1290           microsoft windows vista ultimate upgrade
# 1291  cd269-ar1p= cisco ios enterprise/snasw plus - ...
# 1292  ca olp bps midsize bus win r2 base+50u lic 2y ...
# 1293  apple remote desktop 3 desktop management soft...
# 1294  phillip keveren shannon grama - 501926 - alfre...
# 1295                        adobe premiere elements 3.0
# 1296  ca blapdskapoem30 oem arcserve backup v11.1 wi...
# 1297  w-1rp-f-wx-00 crystal reports xi professional ...
# 1298  jim beloff homespun the joy of uke - vol. 1 & ...
# 1299                    quickstart photo montage studio
#
#                                      google_description  match
# 0     massive collection of images & fonts for all y...      1
# 1                                                            1
# 2     if you're like most nonprofit organizations yo...      1
# 3     learn to sing with the help of a patented real...      1
# 4     adobe after effects pb 6.5 win upgrade.standar...      1
# 5     mia's math adventure tells a captivating story...      1
# 6     kutoka interactive 61208 : mia s math adventur...      1
# 7     disney learning 1st & 2nd features an all-star...      1
# 8     how many times have you heard that it's the th...      1
# 9     a sypware infection is no longer just a matter...      1
# 10    webroot software inc 31250 : a sypware infecti...      1
# 11    for mac media format cd set up a hierarchy of ...      1
# 12    today enterprises and service providers face i...      1
# 13    sonicwall global management system (sonicwall ...      1
# 14    from brain activity to muscular movement circu...      1
# 15    overview meet zachary zebra and the rest of th...      1
# 16    develop fundamental early math skills with mil...      1
# 17    overview with over 87 years of experience and ...      1
# 18    overview this musicalis reference program is t...      1
# 19    overview access powerful images and design too...      1
# 20    new 2005 version! stompsoft's data protection ...      1
# 21    music mermaids and madcap adventures four big ...      1
# 22    multicore intel® processor (adobe® onlocation?...      1
# 23    adobe premiere pro cs3 mac upgrade from premie...      1
# 24    the 1 selling dvd backup solution - bar none! ...      1
# 25    this is the best collection of media based pro...      1
# 26    overview dedicated family research calls for s...      1
# 27    system requirements powerpc g4 or g5 or intel ...      1
# 28    the most engaging informative and imaginative ...      1
# 29    from windows to walls; railings to roofs now y...      1
# ...                                                 ...    ...
# 1270  while the fast and sexy planes such as the f-1...      0
# 1271  take on the roles of robin hood and his merry ...      0
# 1272  this innovative software series enables your d...      0
# 1273  studioâ?¢ ultimate version 11 from pinnacleâ?¢...      0
# 1274  logic express offers the same flexibility reli...      0
# 1275  make the shift from personal computer to perso...      0
# 1276  macintosh: dvd drive sound card & system no in...      0
# 1277  turtle-beach wave 2-0 software for windows tur...      0
# 1278  add style to your laser or inkjet checks!choos...      0
# 1279  dragon naturallyspeaking preferred 9 gives sma...      0
# 1280  system requirements: macintosh os 10.3.x or 10...      0
# 1281  spyware x-terminator 2005 provides constant mo...      0
# 1282  better than any band or artist in recent histo...      0
# 1283  super fast shipping - platinum reseller rating...      0
# 1284  using animations real-time quizzes and a fun i...      0
# 1285  madison media software asams7000 : acid music ...      0
# 1286  encore software 11620 : axis & allies jc puts ...      0
# 1287  challenge your neurons? to fun more brain game...      0
# 1288  fly the navy/marine workhorse fighting machine...      0
# 1289  hp t3558a : usually ships in 24 hours : : hp s...      0
# 1290  windows vista ultimate offers all of the featu...      0
# 1291  cisco systems cd269-ar1p= : usually ships in 2...      0
# 1292                                                         0
# 1293  remote desktop 3 - complete desktop management...      0
# 1294  1. step right up! 2. the carousel 3. hail to t...      0
# 1295  bring your home videos to life! adobe premiere...      0
# 1296  ca blapdskapoem30 oem arcserve backup v11.1 wi...      0
# 1297  business objects w-1rp-f-wx-00 : usually ships...      0
# 1298                 both dvds in one great collection!      0
# 1299  transform your photos into professional-lookin...      0
#
# [2600 rows x 5 columns]

# %%
# create distance features
def cosDist(s1, s2):
    returnDist = 1
    try:
        vecs = TfidfVectorizer().fit_transform([s1,s2]).todense()
        cosDist = cosine(vecs[0], vecs[1])
        if not np.isnan(cosDist):
            returnDist = cosDist 
    except:
        pass
    return returnDist

data["descriptionDistance"] = list(map(lambda x: cosDist(x[0],x[1]), zip(data.google_description, data.amazon_description)))
data["nameDistance"] = list(map(lambda x: cosDist(x[0],x[1]), zip(data.google_name, data.amazon_name)))
# Out:
#                                             amazon_name  \
# 1034                       cakewalk sonar 6 producer ed
# 271                              sony acid music studio
# 1241                                namo webeditor 2006
# 96                                             scrabble
# 784                      canopus 77010158100 let's edit
# 349                        instant landscaping 3.0 [lb]
# 937                pitstop pro 7.0 upgr - 6.x or higher
# 310                         adobe premiere elements 3.0
# 804   handmark oxford american desk dictionary and t...
# 22                  icopydvds2 ultra by digital wunders
# 1246                           webroot desktop firewall
# 1112                         micromat diskstudio ( mac)
# 145                                   cook'n vegetarian
# 29                         instant home design 3.0 [lb]
# 1029  adventure workshop 4th-6th grade 7th ed sb cs ...
# 63               freddi fish 2: the haunted schoolhouse
# 1285                    train sim modeler design studio
# 598                         rise of nations: gold (mac)
# 324         mavis beacon typing 17 deluxe by broderbund
# 1192                         sound forge audio studio 9
# 597                      44 years of the fantastic four
# 698                                internet cleanup 3.0
# 5                    mia's math adventure: just in time
# 653                     best of card games (jewel case)
# 304                             printmaster gold v 17.0
# 759   hp dss software - ( v. 4.0 ) - complete packag...
# 850                                     logic express 7
# 47    web.com site builder & hosting suite sb by web...
# 656             3d home architect landscape designer v8
# 709       onone essentials for adobe photoshop elements
# ...                                                 ...
# 1078  microsoft office student and teacher edition 2...
# 781   microsoft visual studio team suite 2005 with m...
# 845   computrace lojack for laptops - 1 year license...
# 140   panda software antivirus & firewall 2008 - win...
# 407         mavis beacon typing 17 deluxe by broderbund
# 1235                          ultra sudoku/ultra kakuro
# 139         diskeeper 2007 professional single lic pack
# 11                        omnioutliner professional 3.0
# 584              mcafee total protection 2007 - 3 users
# 966           power on now up to date & contact windows
# 602   panda software antivirus & firewall 2008 - win...
# 727                            tiny term emulator v4.3x
# 977    apple remote desktop 2.2 10 client (old version)
# 1217              punch! professional home design suite
# 160   money premium 2007 win32 eng na mini box us on...
# 467                   adobe photoshop cs3 upgrade [mac]
# 686                                 punch! viacad 2d/3d
# 1155                             roxio toast 8 titanium
# 550                          mike garson jazzical suite
# 829                      microsoft onenote 2007 upgrade
# 749                                          monopoly 3
# 843    sony vegas movie studio + dvd 8 platinum edition
# 388                                       window washer
# 1059                  faxstf pro mac os 10.3.9 or above
# 354                zoo tycoon 2: marine mania expansion
# 700                 now up-to-date & contact v5.0 (mac)
# 587                     marketcircle daylite v3.0 (mac)
# 26           family tree maker 11.2 collector's edition
# 805                                      i love the usa
# 512            instant immersion german v2.0 (pc & mac)
#
#                                      amazon_description  \
# 1034  sonar 6 producer is the definitive choice for ...
# 271   acid music studio 6 was designed for the serio...
# 1241  namo webeditor 2006 suite is one of the most c...
# 96    play against one of eight challenging computer...
# 784              canopus (770-10158-100) let's edit 2.0
# 349   instant landscape design 3.0 is the perfect to...
# 937                pitstop pro 7.0 upgr - 6.x or higher
# 310   adobe premiere elements 3.0 software makes cre...
# 804   the oxford american desk dictionary and thesau...
# 22
# 1246  webroot desktop firewall blocks unwanted incom...
# 1112  diskstudio allows you to change the scheme of ...
# 145   featuring recipes for tasty and healthful meat...
# 29    software suite helps you create customized bef...
# 1029  introduce your child to an exciting on-screen ...
# 63    children - ages 3 to 8 everyone knows theres n...
# 1285  with train sim modeler you can create 3d train...
# 598   rise of nations combines the thrills and speed...
# 324         mavis beacon typing 17 deluxe by broderbund
# 1192  sound forge audio studio 9 software is an easy...
# 597   the 44 years of fantastic four dvd lets you re...
# 698   with internet cleanup 3.0 you'll streamline yo...
# 5     in mia's math adventure: just in time children...
# 653   best of card games features over 150 different...
# 304   printmaster gold 17 gives creative home users ...
# 759   - marketing information: hp digital sending so...
# 850   logic express 7.2 gives you the ability to tak...
# 47    web.com's site builder and hosting suite is de...
# 656   with 3d home architect landscape designer 8.0 ...
# 709   make it better cut it out frame it enlarge it!...
# ...                                                 ...
# 1078  graduate to microsoft office 2004 for mac stud...
# 781   microsoft visual studio team suite 2005 progra...
# 845   computrace lojack for laptops is a theft prote...
# 140   now you can be sure that all the information o...
# 407         mavis beacon typing 17 deluxe by broderbund
# 1235  ultra sudoku/kakuro prepares you for hours and...
# 139   diskeeper 2007 is a defrag solution like no ot...
# 11
# 584   today the variety of threats to your pc files ...
# 966   - marketing information: productivity is a lot...
# 602   now you can be sure that all the information o...
# 727   - marketing information: tinyterm provides acc...
# 977   remote desktop 2.2 makes it easier than it's e...
# 1217  12 programs in one intuitive easy-to-use inter...
# 160   model- ms-cd19382wi vendor- microsoft corporat...
# 467   note: this is the upgrade version of adobe pho...
# 686   punch! viacad 2d/3d is a new precision design ...
# 1155  roxio toast 8 sets the standard for burning cd...
# 550   contains the following songs: 1. jazzical suit...
# 829   office onenote 2007 upgrade is a digital noteb...
# 749   monopoly 3 brings the best-selling board game ...
# 843   vegas movie studio+dvd platinum software offer...
# 388                   window washer (win 98 me 2000 xp)
# 1059  faxstf pro serious faxing demands! you can sen...
# 354   zoo tycoon 2: marine mania is a great new expa...
# 700   now up-to-date & contact is the only solution ...
# 587                       market circle daylite ver 3.0
# 26    whether you're an avid family historian or a c...
# 805   uncover geo-facts and discover the people plac...
# 512   with instant immersion german 2.0 you'll have ...
#
#                                             google_name  \
# 1034  cakewalk sonar 6 producers edition software mu...
# 271                                 acid music studio 6
# 1241                   freeverse software toysight gold
# 96     destineer inc 10328 scrabble mac 10.3.8 or later
# 784   sos aggregation company vw - gti racer - topwa...
# 349                     print explosion deluxe 3.0: mac
# 937   enfocus software pp7.0-ug-001 - pitstop pro 7....
# 310                      adobe premiere elements 3 (pc)
# 804   pearson education book: the adobe photoshop li...
# 22    29270077 adobe creative suite 3 web standard -...
# 1246             bling software limited safekeeper plus
# 1112                           micromat inc. diskstudio
# 145        orion/imaginova starry night galaxy explorer
# 29                              instant home design 3.0
# 1029  encore software 11273 - hasbro family collecti...
# 63             freddi fish 2 - case of haunted schl hse
# 1285                           abacus train sim modeler
# 598              destineer rise of nations gold edition
# 324   encore software 10072 - mavis beacon typing 17...
# 1192                           kids power fun for girls
# 597          git 44 years of marvel fantastic 4 dvd-rom
# 698   enfocus software ip4.0-sg-001 - instantpdf 4.0...
# 5     kutoka interactive 61208 mia's math adventure:...
# 653            groove media inc close quarters conflict
# 304   panda software upg to gatdef performa 8200 4k0...
# 759                   system mechanic(r) 5 professional
# 850                             apple logic express 7.2
# 47              susteen data pilot universal essentials
# 656   encore inc 3d home architect landscape designe...
# 709   onone software ele-10211 - on1 essentials v.1....
# ...                                                 ...
# 1078  microsoft office 2004 for students and teacher...
# 781   apple mac os x server tiger - unlimited apple ...
# 845   absolute software lfl-m2-12 - computrace lojac...
# 140                    brain play preschool - 1st grade
# 407                           1000pk multi pack instant
# 1235                   abacus ultra sudoku/ultra kakuro
# 139                         diskeeper 2007 professional
# 11                omnioutliner professional 3.0 for mac
# 584           getting started with sas/af(r) and frames
# 966             git 40 years of marvel avengers dvd-rom
# 602   sos aggregation company panda antivirus + fire...
# 727   century software tt-1 - century tinyterm v.4.3...
# 977   apple software m9953z/a remote desktop 2.2 10 ...
# 1217                      mcafee personal firewall plus
# 160                          money prem 2007 cd minibox
# 467   architecture-centric software project manageme...
# 686                    viacad 2d/3d (win 2000 xp vista)
# 1155  fogware publishing weekly reader ls mastering ...
# 550            mike garson mike garson - jazzical suite
# 829   backup exec 10d win adv disk v10.1 e/f/g/s/i/j...
# 749   ik multimedia groovemaker le live-remixing liv...
# 843   sony media software vegas movie studio + dvd 8...
# 388   daniel gilbert beth marlis musicians institute...
# 1059        allume systems inc - stfmapbx2 - faxstf pro
# 354                              zoo tycoon for windows
# 700   now software num50e1r - up-to-date & contact v...
# 587     daylite v3.0 - marketcircle (mac 10.4 or later)
# 26             family tree maker 11 collector's edition
# 805         emedia music corp guitar pro v 5.1 (hybrid)
# 512   topics entertainment instant immersion german 2.0
#
#                                      google_description  match  \
# 1034  sonar 6 producers edition - multi-track audio/...      1
# 271   make your music more professional and more pow...      1
# 1241  toysight is set of cool games and toys to play...      0
# 96    play against one of eight challenging computer...      1
# 784   gti racer offers the ability to race in new an...      0
# 349   whether you're new to print media or a seasone...      0
# 937   enfocus software pp7.0-ug-001 : enfocus softwa...      1
# 310   key features: create and share videos import v...      1
# 804   book: the adobe photoshop lightroom book: the ...      0
# 22    adobe systems 29270077 : usually ships in 24 h...      0
# 1246  safekeeper is the first software product that ...      0
# 1112  how often have you wished that you could chang...      1
# 145   pilot a starship through intergalactic space b...      0
# 29    from windows to walls; railings to roofs now y...      1
# 1029  encore software 11273 : encore software hasbro...      0
# 63    children - ages 3 to 8 everyone knows there's ...      1
# 1285  microsoft train simulator brings the most real...      1
# 598   system requirements: any macintosh with 600mhz...      1
# 324   encore software 10072 : the top name in typing...      1
# 1192  music mermaids and madcap adventures four big ...      0
# 597                                                          1
# 698   enfocus software ip4.0-sg-001 : enfocus softwa...      0
# 5     mia's math adventure tells a captivating story...      1
# 653   online multiplayer first person shooter: comba...      0
# 304                                                          0
# 759   a totally integrated suite of powerful pc tool...      0
# 850   top reasons to get logic express 7.2 universal...      1
# 47    key features: easy syncing/backups surf the we...      0
# 656   3d home architect® landscape design version 8 ...      1
# 709   onone software ele-10211 : make it better cut ...      1
# ...                                                 ...    ...
# 1078  key features: for mac for student and teachers...      1
# 781   mac os x server tiger software - unlimited v10...      0
# 845   absolute software lfl-m2-12 : a laptop is stol...      1
# 140   boost growing minds with the brain-building ac...      0
# 407                                             pdf 4.0      0
# 1235  sudoku is addicitve sudoku is hot ultra sudoku...      1
# 139   diskeeper 2007 is a defrag solution like no ot...      1
# 11    for mac media format cd set up a hierarchy of ...      1
# 584   this book provides an introduction to applicat...      0
# 966                                                          0
# 602                                                          1
# 727   century software tt-1 : tinyterm provides accu...      1
# 977   the 10-client version allows one administrator...      1
# 1217  protect yourself while online with the advance...      0
# 160   money premium 2007 win32 english north america...      1
# 467   architecture-centered software project plannin...      0
# 686   punch! viacad 2d/3d is a new precision design ...      1
# 1155  developed by educational experts the weekly re...      0
# 550   mike garson is an extraordinary pianist and co...      1
# 829   backup exec 10dwindows advanced disk backup op...      0
# 749   groovemaker 2.5le - loop based live-remixing s...      0
# 843   vegas movie studio software is the easiest way...      1
# 388   this dvd is a comprehensive source for masteri...      0
# 1059  faxstf pro puts robust fax management at your ...      1
# 354   everybody likes the zoo. and why not casual wa...      1
# 700   now software num50e1r : now up-to-date & conta...      1
# 587   designed for the unique needs of mac-based bus...      1
# 26    overview dedicated family research calls for s...      1
# 805   guitar pro is a complete workshop for guitaris...      0
# 512   business trip to berlin? holiday in hamburg? f...      1
#
#       descriptionDistance  nameDistance
# 1034             0.769739  8.056857e-01
# 271              0.796791  2.234855e-01
# 1241             0.670588  1.000000e+00
# 96               0.141743  7.403020e-01
# 784              1.000000  1.000000e+00
# 349              0.948874  1.000000e+00
# 937              0.664824  4.202613e-01
# 310              0.685031  2.234855e-01
# 804              0.920297  1.000000e+00
# 22               1.000000  1.000000e+00
# 1246             0.851847  1.000000e+00
# 1112             0.579378  4.968974e-01
# 145              0.835793  1.000000e+00
# 29               0.851147  2.234855e-01
# 1029             0.986838  8.549595e-01
# 63               0.502070  6.553579e-01
# 1285             0.823901  4.898510e-01
# 598              0.903708  4.196670e-01
# 324              0.943878  2.641031e-01
# 1192             0.758369  1.000000e+00
# 597              1.000000  5.887929e-01
# 698              1.000000  1.000000e+00
# 5                0.771561  2.907027e-01
# 653              0.919949  1.000000e+00
# 304              1.000000  1.000000e+00
# 759              0.825953  1.000000e+00
# 850              0.824264  2.907027e-01
# 47               0.949072  1.000000e+00
# 656              0.780807  3.672095e-01
# 709              0.477678  7.097093e-01
# ...                   ...           ...
# 1078             0.798840  6.639031e-01
# 781              0.880457  1.000000e+00
# 845              0.721563  4.459406e-01
# 140              0.831253  1.000000e+00
# 407              1.000000  1.000000e+00
# 1235             0.663071  1.326363e-01
# 139              0.415534  4.202613e-01
# 11               1.000000  4.202613e-01
# 584              0.825138  1.000000e+00
# 966              1.000000  1.000000e+00
# 602              1.000000  5.887929e-01
# 727              0.525472  9.430025e-01
# 977              0.803277  4.413822e-01
# 1217             0.838295  1.000000e+00
# 160              0.928004  7.375791e-01
# 467              0.956826  1.000000e+00
# 686              0.508012  5.926474e-01
# 1155             0.868730  1.000000e+00
# 550              0.909424  5.131670e-02
# 829              1.000000  1.000000e+00
# 749              0.838976  1.000000e+00
# 843              0.612263  2.004810e-01
# 388              1.000000  1.000000e+00
# 1059             0.617500  8.155681e-01
# 354              0.659290  7.087806e-01
# 700              0.756753  5.790908e-01
# 587              1.000000  3.651912e-01
# 26               0.813521 -2.220446e-16
# 805              0.882598  1.000000e+00
# 512              0.794919  6.191274e-01
#
# [2071 rows x 7 columns]

# %%
# split data for cross validation
data = data.iloc[np.random.permutation(data.shape[0])]
msk = np.random.rand(data.shape[0]) < .8
train = data[msk]
test = data[~msk]
trainData, trainLabels = train[['nameDistance', 'descriptionDistance']], train['match']
testData, testLabels = test[['nameDistance', 'descriptionDistance']], test['match']

# %%
# fit and test a model
clf = RandomForestClassifier(100)
clf.fit(trainData, trainLabels)
preds = clf.predict(testData)
print("accuracy:\n" + str(np.mean(preds==testLabels)))
test.loc[preds!=testLabels]
# Out:
# accuracy:
# 0.981096408318
#                                             amazon_name  \
# 1170  money home & business 2007 win32 eng na mini b...
# 212   is3 stopzilla 4.0 [stop spyware pop-ups id theft]
# 1177                                   the movies (mac)
# 275             student home learning system for pc/mac
# 501     lego star wars ii: the original trilogy for mac
# 797                         acad corel painter x pc/mac
# 494   microsoft windows terminal server 2003 client ...
# 865                              adobe premiere pro cs3
# 551                              adobe premiere pro cs3
# 1126        spring cleaning 9.0 for mac os 10.4 & above
#
#                                      amazon_description  \
# 1170  model- ms-cd19383wi vendor- microsoft corporat...
# 212         stopzilla 4.0 spyware protection - mini box
# 1177  the movies answers a question that many of us ...
# 275   the fogware student home learning system is on...
# 501   lego star wars ii sets players loose in the or...
# 797   - marketing information: painter x the worldan...
# 494   terminal server lets you deliver windows-based...
# 865   tell your story with maximum impact using adob...
# 551   tell your story with maximum impact using adob...
# 1126  spring cleaning 9 secures your privacy and cle...
#
#                                             google_name  \
# 1170      myob accounting plus/accountedge additional u
# 212                           stopzilla! 4.0 (pc) roxio
# 1177                        adobe illustrator cs3 (mac)
# 275                          pxl smartscale for mac/win
# 501   novell identity manager integration module for...
# 797                                premiere pro cs3 mac
# 494        win 2003 ter svr cal 5pk microsoft r19-00846
# 865            adobe(r) photoshop(r) 7.0 upgrade for pc
# 551   adobe photoshop cs3 extended - complete packag...
# 1126  adobe after effects cs3 professional software ...
#
#                                      google_description  match  \
# 1170  designed to help get your business get up and ...      0
# 212   key features: detects/destroys spyware stops p...      1
# 1177  key features: live color live trace live paint...      0
# 275                                 one image any size.      0
# 501                   mod3 mainframe lics+1yr mnt vlal1      0
# 797   adobe premiere pro cs3 mac. make every frame c...      0
# 494   model- ms28736nt vendor- microsoft features- w...      1
# 865   with versatility of its tools the adobe photos...      0
# 551   ideal for film video and multimedia profession...      0
# 1126  after effects cs3 professional software for ma...      0
#
#       descriptionDistance  nameDistance
# 1170             0.606781      1.000000
# 212              0.932564      0.883282
# 1177             1.000000      0.829224
# 275              0.970236      0.793863
# 501              1.000000      0.895448
# 797              0.751229      0.872640
# 494              0.897679      0.886959
# 865              0.763237      0.872640
# 551              0.614225      0.805686
# 1126             0.811649      0.885532

# %%
# find price differences for matched products

priceData = pd.merge(amazon, amazon_google, left_on="id", right_on="idAmazon")
priceData = pd.merge(priceData, google, left_on="idGoogleBase", right_on="id")
priceData = priceData[['title', 'idAmazon', 'price_x', 'name',  'idGoogleBase', 'price_y']]
priceData.columns = ['amazon_name', 'amazon_id'
                     , 'amazon_price', 'google_name', 'google_id', 'google_price']

def floatMe(s):
    try:
        return float(s)
    except:
        return 0
    
priceData['amazon_price'] = priceData.amazon_price.map(floatMe)
priceData['google_price'] = priceData.google_price.map(floatMe)

priceData = priceData.loc[priceData.amazon_price!=0]
priceData = priceData.loc[priceData.google_price!=0]

priceData['priceDiff'] = priceData.amazon_price - priceData.google_price
priceData = priceData.sort('priceDiff')
priceData
# Out:
#                                             amazon_name   amazon_id  \
# 114         watchguard serverlock manager (100 servers)  b00005atxo
# 456   steinberg halion symphonic orchestra virtual i...  b000k6b2l0
# 575             adobe photoshop cs2 (mac) [old version]  b00081i6ji
# 494   microsoft windows terminal server 2003 client ...  b00008mnxz
# 425       adobe creative suite cs3 design premium [mac]  b000ndibri
# 1009                              aquazone bass edition  b000gaqlxe
# 321   serious magic ultra2 master sets library 2 ( w...  b0009yx9by
# 388          adobe creative suite cs3 web premium [mac]  b000ndibvo
# 1011  adobe creative suite cs3 master collection upsell  b000ndibl4
# 742         adobe creative suite cs3 production premium  b000ogsyjy
# 495   microsoft windows terminal server 2003 client ...  b00008mnxz
# 413      adobe creative suite cs3 design standard [mac]  b000ndible
# 771   adobe creative suite cs3 master collection upg...  b000ndibkk
# 395                       adobe dreamweaver cs3 upgrade  b000ndid4y
# 1088        adobe creative suite cs3 web standard [mac]  b000ndibge
# 251   adobe creative suite cs3 web premium upsell [mac]  b000ndibws
# 757   adobe creative suite cs3 production premium up...  b000ogsh3c
# 211   adobe creative suite cs3 design standard upsel...  b000ndibnc
# 447                              adobe premiere pro cs3  b000ofnrhy
# 1213                            adobe after effects cs3  b000oftj8u
# 169                            adobe indesign cs3 [mac]  b000ndibci
# 1123  stubbs the zombie in rebel without a pulse (dv...  b000b6n2oe
# 474                           adobe flash pro cs3 [mac]  b000ndicpy
# 573   adobe creative suite cs3 production premium up...  b000ofnri8
# 23                       adobe premiere pro cs3 upgrade  b000o24l3q
# 1284  adobe creative suite cs3 web standard upsell [...  b000ndibhi
# 613                         adobe illustrator cs3 [mac]  b000ndib8m
# 341   adobe creative suite cs3 design premium upgrad...  b000o27t8a
# 1038           crystal 3d impact! pro 1.25 (jewel case)  b00002s755
# 815                           leave the lights on (mac)  b0000vmimw
# ...                                                 ...         ...
# 730   quickbooks point-of-sale pro with hardware bun...  b000hbvvka
# 451              entertainment partners budgeting (mac)  b0001nm7zm
# 647   hp dss software - ( v. 4.0 ) - complete packag...  b0006nkbn2
# 679   motu digital performer 5 digital audio softwar...  b000fiej4k
# 303   tinyterm v4.x 5u windows terminal emulation (t...  b00006rgnx
# 173                microsoft office small business 2007  b000kzf7oo
# 1034                       cakewalk sonar 6 producer ed  b000iw5kv4
# 106                  quickbooks pos: pro multistore 6.0  b000i2qubi
# 861                     cubase 4 competitive crossgrade  b000n28264
# 157   crystal reports 11 professional full product f...  b000b5ue6y
# 391                           dv rack 2 win retail ue1u  b000lz6a5i
# 682                           avid liquid vs 7 software  b000e0v924
# 1037                                adobe captivate 2.0  b000iaolaw
# 558           steinberg nuendo 3 digital audio software  b000a2zlam
# 678                                        sony vegas 6  b000e13es0
# 677                                      vegas 6 for pc  b000h5fo8g
# 1136                     adobe framemaker 7.2 (windows)  b000bdezfw
# 154   backup exec 10d win adv disk v10.1 lic only (e...  b000bw7kxw
# 422                  flash remoting 1 alp ret eng cd 1u  b000cs3s2m
# 120                           pantone reference library  b000e6q3em
# 667   microsoft visual studio team suite 2005 with m...  b000barbaq
# 551                                     avid liquid pro  b000cqpc32
# 1294                 flash remoting 1 alp ret eng cd 2u  b000cs3s2c
# 105   microsoft licenses win svr 2003 ext conn lic (...  b0006g31i6
# 81    microsoft licenses project svr sa govt (h2200301)  b0006g2wke
# 272   microsoft licenses biztalk hipaa std. sa only ...  b0006g2tum
# 136                            espro + interpretair s/w  b000bi7uqs
# 150   adobe acrobat distiller svr v6-cd sun 100u ( 4...  b0000y7wck
# 113   microsoft licenses exch. srvr extrn conn sa en...  b0006g31ao
# 122   microsoft licenses sps extrnlconnnonemplyengla...  b0006g2zce
#
#       amazon_price                                        google_name  \
# 114       14995.00                   serverlock manager - 100 servers
# 456         374.99  steinberg software halion symphonic orchestra ...
# 575         649.00  adobe systems inc 13102124 adobe photoshop cs ...
# 494         669.00       win 2003 ter svr cal 5pk microsoft r19-00846
# 425        1799.00                           adobe cs3 design premium
# 1009         19.99            allume checkit system performance suite
# 321         276.50  serious magic ultra master sets library 1 effe...
# 388        1599.00                              adobe cs3 web premium
# 1011       1999.00        adobe cs3 master collection upsell from cs1
# 742        1699.00                       adobe cs3 production premium
# 495         669.00  microsoft windows terminal server 2003 client ...
# 413        1199.00                          adobe cs3 design standard
# 771        1399.00        adobe cs3 master collection upsell from cs2
# 395         199.00              adobe dreamweaver cs3 upgrade windows
# 1088        999.00                             adobe cs3 web standard
# 251        1399.00                       adobe cs3 web premium upsell
# 757        1199.00                adobe cs3 production premium upsell
# 211         899.00                   adobe cs3 design standard upsell
# 447         799.00                             adobe premiere pro cs3
# 1213        999.00                            adobe cs3 after effects
# 169         699.00                         adobe indesign cs3 for mac
# 1123          9.99                            aspyr stubbs the zombie
# 474         699.00                       adobe cs3 flash professional
# 573         799.00               adobe cs3 production premium upgrade
# 23          299.00                       premiere pro cs3 mac upgrade
# 1284        799.00                      adobe cs3 web standard upsell
# 613         599.00                      adobe illustrator cs3 for mac
# 341         599.00                   adobe cs3 design premium upgrade
# 1038         79.00  crystal-graphics crystal 3d impact! pro animat...
# 815           9.99                   aspyr leave the lights on-bundle
# ...            ...                                                ...
# 730        1749.95                      qb pos 6.0 pro solution hw/sw
# 451         699.00       entertainment partners ep budgeting for film
# 647         630.36  hewlett packard t1936aa ua0 - hp digital sendi...
# 679         795.00        motu dp5 software music production software
# 303         705.21  century software tt-5 - century tinyterm v.4.2...
# 173         735.33          microsoft w87-02380 office sbe 2007 win32
# 1034        799.00  cakewalk sonar 6 producers edition software mu...
# 106        1399.95                      qb pos 6.0 pro multi store sw
# 861         549.99  steinberg cubase studio 4 software - competiti...
# 157         909.66  crystal reports xi professional edition - comp...
# 391         908.69  adobe dv rack 2.0 hd software for windows prof...
# 682         888.75  avid liquid 7.0 - professional video editing s...
# 1037       1083.95  adobe captivate 2 software for windows present...
# 558        2499.00       steinberg nuendo 3 music production software
# 678         599.95  sony vegas 6 video editing software profession...
# 677         599.99  sony vegas 6 video editing software profession...
# 1136       1445.90  adobe systems 27910468 adobe framemaker v.7.2 ...
# 154         983.34  backup exec 10d win adv disk v10.1 e/f/g/s/i/j...
# 422        1657.06  adobe systems inc flash remoting 1.0 (net&java...
# 120        1623.06                 pantone gps206 - reference library
# 667       10949.00  microsoft 121-00324 - visual studio team suite...
# 551        1942.60  avid liquid pro 7.0 video editing hardware/sof...
# 1294       3314.09  adobe systems inc flash remoting 1.0 (net&java...
# 105        3371.85     microsoft r39-00292 open win svr 2003 ext conn
# 81         3601.40  microsoft h22-00301 gov open sa project svr w9...
# 272        4215.77  microsoft u02-00024 open sa biztalk hipaa accl...
# 136        5750.60  fluke networks intair-lap - interpretair wlan ...
# 150        9104.19  adobe 42050106 acrobat distiller svr v6-cd sun...
# 113       42166.22  microsoft 394-00416 opens exch svr exconn l/sa...
# 122      101515.55  microsoft h32-00034 sps extrnlconnnonemplyengl...
#
#                                               google_id  google_price  \
# 114   http://www.google.com/base/feeds/snippets/1143...      56543.88
# 456   http://www.google.com/base/feeds/snippets/1783...        545.51
# 575   http://www.google.com/base/feeds/snippets/1841...        788.63
# 494   http://www.google.com/base/feeds/snippets/1838...        762.95
# 425   http://www.google.com/base/feeds/snippets/2224...       1865.99
# 1009  http://www.google.com/base/feeds/snippets/1382...         84.99
# 321   http://www.google.com/base/feeds/snippets/5238...        339.95
# 388   http://www.google.com/base/feeds/snippets/5767...       1659.99
# 1011  http://www.google.com/base/feeds/snippets/1499...       2054.99
# 742   http://www.google.com/base/feeds/snippets/1657...       1749.99
# 495   http://www.google.com/base/feeds/snippets/9445...        719.04
# 413   http://www.google.com/base/feeds/snippets/7907...       1243.99
# 771   http://www.google.com/base/feeds/snippets/4247...       1437.99
# 395   http://www.google.com/base/feeds/snippets/1838...        236.74
# 1088  http://www.google.com/base/feeds/snippets/1227...       1035.99
# 251   http://www.google.com/base/feeds/snippets/9484...       1434.99
# 757   http://www.google.com/base/feeds/snippets/2640...       1234.99
# 211   http://www.google.com/base/feeds/snippets/1640...        934.99
# 447   http://www.google.com/base/feeds/snippets/9526...        825.99
# 1213  http://www.google.com/base/feeds/snippets/4224...       1025.99
# 169   http://www.google.com/base/feeds/snippets/5536...        725.99
# 1123  http://www.google.com/base/feeds/snippets/8481...         35.99
# 474   http://www.google.com/base/feeds/snippets/4287...        724.99
# 573   http://www.google.com/base/feeds/snippets/2217...        822.99
# 23    http://www.google.com/base/feeds/snippets/9489...        320.25
# 1284  http://www.google.com/base/feeds/snippets/8042...        819.99
# 613   http://www.google.com/base/feeds/snippets/2927...        619.99
# 341   http://www.google.com/base/feeds/snippets/1834...        619.99
# 1038  http://www.google.com/base/feeds/snippets/1946...         99.95
# 815   http://www.google.com/base/feeds/snippets/1836...         29.99
# ...                                                 ...           ...
# 730   http://www.google.com/base/feeds/snippets/1339...       1474.99
# 451   http://www.google.com/base/feeds/snippets/8829...        415.99
# 647   http://www.google.com/base/feeds/snippets/8709...        342.97
# 679   http://www.google.com/base/feeds/snippets/1530...        499.95
# 303   http://www.google.com/base/feeds/snippets/6732...        395.97
# 173   http://www.google.com/base/feeds/snippets/1839...        400.34
# 1034  http://www.google.com/base/feeds/snippets/1756...        459.95
# 106   http://www.google.com/base/feeds/snippets/1283...       1054.99
# 861   http://www.google.com/base/feeds/snippets/9029...        199.99
# 157   http://www.google.com/base/feeds/snippets/1839...        537.57
# 391   http://www.google.com/base/feeds/snippets/1683...        499.00
# 682   http://www.google.com/base/feeds/snippets/3852...        439.95
# 1037  http://www.google.com/base/feeds/snippets/2919...        598.95
# 558   http://www.google.com/base/feeds/snippets/1904...       1999.99
# 678   http://www.google.com/base/feeds/snippets/1698...         99.00
# 677   http://www.google.com/base/feeds/snippets/1698...         99.00
# 1136  http://www.google.com/base/feeds/snippets/1843...        881.00
# 154   http://www.google.com/base/feeds/snippets/1839...        309.99
# 422   http://www.google.com/base/feeds/snippets/1750...        964.22
# 120   http://www.google.com/base/feeds/snippets/1843...        907.97
# 667   http://www.google.com/base/feeds/snippets/1248...      10015.97
# 551   http://www.google.com/base/feeds/snippets/1838...        899.00
# 1294  http://www.google.com/base/feeds/snippets/1771...       1928.09
# 105   http://www.google.com/base/feeds/snippets/1840...       1863.78
# 81    http://www.google.com/base/feeds/snippets/1842...       1995.12
# 272   http://www.google.com/base/feeds/snippets/1835...       2335.47
# 136   http://www.google.com/base/feeds/snippets/1840...       3277.97
# 150   http://www.google.com/base/feeds/snippets/1839...       5399.99
# 113   http://www.google.com/base/feeds/snippets/1844...      22575.14
# 122   http://www.google.com/base/feeds/snippets/1682...      55420.56
#
#       priceDiff
# 114   -41548.88
# 456     -170.52
# 575     -139.63
# 494      -93.95
# 425      -66.99
# 1009     -65.00
# 321      -63.45
# 388      -60.99
# 1011     -55.99
# 742      -50.99
# 495      -50.04
# 413      -44.99
# 771      -38.99
# 395      -37.74
# 1088     -36.99
# 251      -35.99
# 757      -35.99
# 211      -35.99
# 447      -26.99
# 1213     -26.99
# 169      -26.99
# 1123     -26.00
# 474      -25.99
# 573      -23.99
# 23       -21.25
# 1284     -20.99
# 613      -20.99
# 341      -20.99
# 1038     -20.95
# 815      -20.00
# ...         ...
# 730      274.96
# 451      283.01
# 647      287.39
# 679      295.05
# 303      309.24
# 173      334.99
# 1034     339.05
# 106      344.96
# 861      350.00
# 157      372.09
# 391      409.69
# 682      448.80
# 1037     485.00
# 558      499.01
# 678      500.95
# 677      500.99
# 1136     564.90
# 154      673.35
# 422      692.84
# 120      715.09
# 667      933.03
# 551     1043.60
# 1294    1386.00
# 105     1508.07
# 81      1606.28
# 272     1880.30
# 136     2472.63
# 150     3704.20
# 113    19591.08
# 122    46094.99
#
# [1163 rows x 7 columns]
